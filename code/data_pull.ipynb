# %%
# DONE : import files into data folder
# NOTE : Kaggle username/API key needs to be stored in .env
# Variable names : KAGGLE_USERNAME, KAGGLE_API_TOKEN

from dotenv import load_dotenv
import os

load_dotenv()

# !kaggle datasets download -d miadul/brain-tumor-mri-dataset -p ../data --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/miadul/brain-tumor-mri-dataset
# License(s): apache-2.0
# ...
#   0%|          | 0.00/236M [00:00<?, ?B/s]
#   1%|          | 2.00M/236M [00:00<00:11, 20.6MB/s]
#   3%|▎         | 6.00M/236M [00:00<00:08, 29.6MB/s]
#   5%|▌         | 12.0M/236M [00:00<00:05, 41.2MB/s]
#   7%|▋         | 16.0M/236M [00:00<00:06, 36.0MB/s]
#   9%|▉         | 22.0M/236M [00:00<00:05, 43.4MB/s]
#  11%|█▏        | 27.0M/236M [00:00<00:04, 44.0MB/s]
#  14%|█▎        | 32.0M/236M [00:00<00:04, 44.6MB/s]
#  16%|█▌        | 37.0M/236M [00:00<00:04, 44.7MB/s]
#  18%|█▊        | 42.0M/236M [00:01<00:04, 44.8MB/s]
#  20%|█▉        | 47.0M/236M [00:01<00:04, 44.7MB/s]
#  22%|██▏       | 52.0M/236M [00:01<00:04, 44.4MB/s]
#  24%|██▍       | 57.0M/236M [00:01<00:04, 44.3MB/s]
#  26%|██▌       | 62.0M/236M [00:01<00:04, 44.5MB/s]
#  28%|██▊       | 67.0M/236M [00:01<00:03, 45.4MB/s]
#  30%|███       | 72.0M/236M [00:01<00:03, 44.8MB/s]
# ...
